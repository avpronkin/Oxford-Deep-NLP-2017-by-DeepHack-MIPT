# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
import sys
print(sys.version)
import numpy
numpy.show_config()
#I need optimization. Next homework TODO
#from numpy._distributor_init import NUMPY_MKL
#print(NUMPY_MKL)
# Out:
# 3.5.2 |Anaconda 4.3.1 (64-bit)| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]
# openblas_lapack_info:
#   NOT AVAILABLE
# openblas_info:
#   NOT AVAILABLE
# blis_info:
#   NOT AVAILABLE
# lapack_mkl_info:
#   NOT AVAILABLE
# blas_mkl_info:
#   NOT AVAILABLE
# atlas_3_10_blas_threads_info:
#     language = c
#     libraries = ['numpy-atlas']
#     define_macros = [('HAVE_CBLAS', None), ('ATLAS_INFO', '"\\"None\\""')]
#     library_dirs = ['C:\\projects\\numpy-wheels\\windows-wheel-builder\\atlas-builds\\atlas-3.11.38-sse2-64\\lib']
# lapack_opt_info:
#     language = f77
#     libraries = ['numpy-atlas', 'numpy-atlas']
#     define_macros = [('ATLAS_INFO', '"\\"None\\""')]
#     library_dirs = ['C:\\projects\\numpy-wheels\\windows-wheel-builder\\atlas-builds\\atlas-3.11.38-sse2-64\\lib']
# atlas_3_10_threads_info:
#     language = f77
#     libraries = ['numpy-atlas', 'numpy-atlas']
#     define_macros = [('ATLAS_INFO', '"\\"None\\""')]
#     library_dirs = ['C:\\projects\\numpy-wheels\\windows-wheel-builder\\atlas-builds\\atlas-3.11.38-sse2-64\\lib']
# blas_opt_info:
#     language = c
#     libraries = ['numpy-atlas']
#     define_macros = [('HAVE_CBLAS', None), ('ATLAS_INFO', '"\\"None\\""')]
#     library_dirs = ['C:\\projects\\numpy-wheels\\windows-wheel-builder\\atlas-builds\\atlas-3.11.38-sse2-64\\lib']

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# 22717696
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-9402be12f283> in <module>()
#      14   return filename
#      15
# ---> 16 filename = maybe_download('text8.zip', 31344016)
#
# <ipython-input-11-9402be12f283> in maybe_download(filename, expected_bytes)
#      11     print(statinfo.st_size)
#      12     raise Exception(
# ---> 13       'Failed to verify ' + filename + '. Can you get to it with a browser?')
#      14   return filename
#      15
#
# Exception: Failed to verify text8.zip. Can you get to it with a browser?

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
filename="C:/Users/Alexis/Jupyter Notebooks/text8.zip"
words = read_data(filename)
#words = tf.compat.as_str(read()).split()
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print(batch)
    
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# [3083 3083   12   12    6    6  195  195]
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
# [12 12 12 12  6  6  6  6]
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.185048
# Nearest to be: quartets, fireman, risk, ln, moods, graduation, territorial, panoramas,
# Nearest to also: moles, rowspan, dearth, ostara, captains, kolmogorov, singles, divisors,
# Nearest to have: condensate, johanna, cursor, shang, mtu, cheltenham, drones, view,
# Nearest to years: changeable, gaseous, archetypical, burgundy, u, molinari, vines, demonstrators,
# Nearest to system: modell, commandant, xyz, hus, speedway, affirming, buses, tank,
# Nearest to united: chakras, iole, undersea, heidi, ether, flushing, recounts, embryonic,
# Nearest to used: capitalised, peyote, ticonderoga, ska, rationale, brac, automatically, belted,
# Nearest to not: rails, monochromatic, accumulate, dishonesty, tory, kutch, sand, predominates,
# Nearest to were: socrates, bernoulli, drenthe, veterans, disquieting, troubles, morrie, celebrate,
# Nearest to it: intercepted, tights, unisex, inside, wields, geographical, amygdalin, in,
# Nearest to was: slovakia, norad, carniola, ancona, gladly, potions, couple, customer,
# Nearest to zero: galleries, crosstown, alumnus, citations, undetermined, brains, drought, bremer,
# Nearest to d: corrupting, dilation, supervisors, qur, ec, narmada, haemoglobin, bern,
# Nearest to however: holds, saturday, pham, exclaimed, theophilus, rapid, goth, genevieve,
# Nearest to on: bone, aleutian, enchantment, nanna, jehu, tutte, divergences, incumbents,
# Nearest to this: doo, declined, threatens, candela, brane, chase, luthiers, monologue,
# Average loss at step 2000: 4.368769
# Average loss at step 4000: 3.859545
# Average loss at step 6000: 3.787985
# Average loss at step 8000: 3.688300
# Average loss at step 10000: 3.617169
# Nearest to be: have, is, was, originated, been, are, by, virtues,
# Nearest to also: not, algal, which, ostara, thulsa, it, hiring, disadvantage,
# Nearest to have: had, be, has, were, are, generalship, neurotransmitter, conjugation,
# Nearest to years: gaseous, burgundy, vines, changeable, zaghawa, lovecraft, molinari, pouring,
# Nearest to system: commandant, xyz, speedway, monitors, affirming, sasson, pedals, weak,
# Nearest to united: chakras, iole, undersea, embryonic, indentations, ether, heidi, yeti,
# Nearest to used: peyote, awakened, parson, defined, unofficially, finned, automatically, burzum,
# Nearest to not: also, they, it, she, he, often, sharon, to,
# Nearest to were: are, have, was, gershwin, drenthe, chiba, is, veterans,
# Nearest to it: he, this, they, there, which, not, intercepted, devalued,
# Nearest to was: is, has, by, had, were, be, been, confer,
# Nearest to zero: five, nine, eight, seven, four, six, three, two,
# Nearest to d: b, dilation, corrupting, algol, ec, bern, narmada, fremantle,
# Nearest to however: holds, militia, abe, beaten, retrograde, forgot, issuer, changed,
# Nearest to on: in, greenville, encased, bearer, victoriae, zapotec, trends, by,
# Nearest to this: it, the, a, which, spaulding, any, parsons, forgetfulness,
# Average loss at step 12000: 3.601788
# Average loss at step 14000: 3.572980
# Average loss at step 16000: 3.411170
# Average loss at step 18000: 3.456341
# Average loss at step 20000: 3.541375
# Nearest to be: have, been, is, by, was, originated, are, being,
# Nearest to also: which, algal, not, ostara, now, it, generally, who,
# Nearest to have: had, has, be, were, are, jeeps, having, prefer,
# Nearest to years: gaseous, burgundy, hesitant, molinari, meritocracy, matured, questions, geoid,
# Nearest to system: xyz, commandant, pepin, monitors, terribly, weak, avenge, language,
# Nearest to united: chakras, iole, undersea, embryonic, indentations, ether, covariant, usa,
# Nearest to used: known, peyote, referred, defined, parson, found, marta, able,
# Nearest to not: also, sharon, bribery, always, it, they, icmp, dimensionality,
# Nearest to were: are, was, had, have, be, is, bristol, discredited,
# Nearest to it: he, there, this, they, she, which, also, now,
# Nearest to was: is, had, were, has, been, became, be, confer,
# Nearest to zero: five, seven, four, six, nine, eight, three, two,
# Nearest to d: b, dilation, hallucinations, corrupting, seperate, coincidentally, baum, exaggeration,
# Nearest to however: but, holds, issuer, thinks, changed, that, forgot, prompt,
# Nearest to on: in, during, pinkish, bearer, at, upon, bedroom, philosophie,
# Nearest to this: it, which, a, the, that, comes, resignations, parsons,
# Average loss at step 22000: 3.503916
# Average loss at step 24000: 3.492898
# Average loss at step 26000: 3.477653
# Average loss at step 28000: 3.482339
# Average loss at step 30000: 3.502712
# Nearest to be: been, have, were, being, is, modernisation, are, sapiens,
# Nearest to also: generally, now, which, algal, it, then, still, often,
# Nearest to have: had, has, were, be, are, having, sous, jeeps,
# Nearest to years: days, months, gaseous, year, hesitant, geoid, stg, redding,
# Nearest to system: xyz, commandant, administering, monitors, systems, ptolemy, leq, pepin,
# Nearest to united: chakras, undersea, iole, indentations, ether, usa, embryonic, root,
# Nearest to used: known, referred, found, peyote, defined, seen, parson, forgiving,
# Nearest to not: they, often, still, it, bribery, generally, there, always,
# Nearest to were: are, have, had, was, be, been, is, but,
# Nearest to it: he, this, there, they, she, which, never, also,
# Nearest to was: is, has, had, were, became, been, when, yeni,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to d: b, seperate, dilation, corrupting, baum, ec, exaggeration, cram,
# Nearest to however: but, holds, that, when, robustness, issuer, forgot, saturday,
# Nearest to on: in, through, upon, during, at, greenville, under, zapotec,
# Nearest to this: which, it, what, that, pizarro, parsons, spaulding, eldridge,
# Average loss at step 32000: 3.501202
# Average loss at step 34000: 3.491350
# Average loss at step 36000: 3.452053
# Average loss at step 38000: 3.301564
# Average loss at step 40000: 3.430823
# Nearest to be: been, have, was, being, is, were, are, legally,
# Nearest to also: often, now, which, generally, still, sometimes, usually, who,
# Nearest to have: had, has, were, be, are, jeeps, having, refer,
# Nearest to years: days, months, year, times, starts, redding, decades, gaseous,
# Nearest to system: systems, xyz, ptolemy, commandant, tank, monitors, administering, hubei,
# Nearest to united: chakras, iole, usa, indentations, undersea, ether, fra, covariant,
# Nearest to used: known, referred, found, available, seen, defined, able, considered,
# Nearest to not: they, still, generally, often, it, usually, never, also,
# Nearest to were: are, have, was, had, those, been, be, siddha,
# Nearest to it: he, there, she, this, they, which, but, that,
# Nearest to was: is, has, became, had, were, been, be, recorders,
# Nearest to zero: seven, five, nine, eight, six, four, two, three,
# Nearest to d: b, UNK, seperate, baum, dilation, roger, wend, exaggeration,
# Nearest to however: but, though, while, that, although, when, should, issuer,
# Nearest to on: upon, during, at, through, in, pinkish, about, between,
# Nearest to this: which, it, the, that, any, unexplained, eldridge, resignations,
# Average loss at step 42000: 3.437822
# Average loss at step 44000: 3.452174
# Average loss at step 46000: 3.445183
# Average loss at step 48000: 3.357419
# Average loss at step 50000: 3.382079
# Nearest to be: have, being, been, was, were, is, sapiens, are,
# Nearest to also: now, often, which, still, sometimes, then, who, actually,
# Nearest to have: had, has, were, be, are, having, prefer, refer,
# Nearest to years: days, months, year, decades, redding, times, starts, achieves,
# Nearest to system: systems, xyz, leq, administering, commandant, affirming, tank, hoosiers,
# Nearest to united: chakras, usa, fra, gerrymandering, kilometre, indentations, iole, netting,
# Nearest to used: known, referred, able, found, available, written, seen, considered,
# Nearest to not: generally, still, able, never, usually, they, sharon, almost,
# Nearest to were: are, have, was, had, is, be, been, those,
# Nearest to it: he, she, there, they, this, which, still, now,
# Nearest to was: is, became, has, were, had, be, by, becomes,
# Nearest to zero: five, eight, seven, nine, six, four, three, two,
# Nearest to d: b, dilation, seperate, roger, r, wend, baum, exaggeration,
# Nearest to however: but, although, while, though, when, that, where, and,
# Nearest to on: upon, in, through, around, zapotec, pinkish, into, spines,
# Nearest to this: which, it, the, ouadda, that, he, there, some,
# Average loss at step 52000: 3.437342
# Average loss at step 54000: 3.426676
# Average loss at step 56000: 3.438980
# Average loss at step 58000: 3.397774
# Average loss at step 60000: 3.393449
# Nearest to be: been, being, is, have, was, become, conceives, explain,
# Nearest to also: now, often, still, sometimes, usually, generally, originally, commonly,
# Nearest to have: had, has, having, are, were, produce, be, knowledgeable,
# Nearest to years: days, months, year, decades, redding, times, stg, mur,
# Nearest to system: systems, hoosiers, peptides, units, xyz, office, administering, capcom,
# Nearest to united: chakras, usa, covariant, indentations, netting, fra, kilometre, armed,
# Nearest to used: known, referred, seen, designed, written, defined, considered, found,
# Nearest to not: still, generally, never, sharon, able, they, usually, also,
# Nearest to were: are, was, had, have, those, employing, including, been,
# Nearest to it: he, she, there, this, they, still, which, that,
# Nearest to was: is, had, became, has, were, although, be, becomes,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to d: b, baum, dilation, r, seperate, entente, c, wend,
# Nearest to however: but, although, though, that, which, while, when, nevertheless,
# Nearest to on: upon, through, in, zapotec, pinkish, about, cui, vardar,
# Nearest to this: which, it, there, that, the, some, still, what,
# Average loss at step 62000: 3.243329
# Average loss at step 64000: 3.253926
# Average loss at step 66000: 3.404401
# Average loss at step 68000: 3.398163
# Average loss at step 70000: 3.366366
# Nearest to be: been, is, easily, being, were, have, was, become,
# Nearest to also: now, still, often, sometimes, which, usually, actually, sulba,
# Nearest to have: had, has, were, having, are, be, produce, knowledgeable,
# Nearest to years: days, months, decades, year, redding, times, weeks, stg,
# Nearest to system: systems, hoosiers, process, rhodope, units, tank, angevin, cooks,
# Nearest to united: chakras, armed, usa, fra, indentations, covariant, communist, kilometre,
# Nearest to used: known, referred, seen, written, designed, found, applied, described,
# Nearest to not: still, never, generally, almost, now, usually, able, they,
# Nearest to were: are, had, have, was, be, those, been, including,
# Nearest to it: he, she, there, this, they, still, which, god,
# Nearest to was: is, has, had, were, became, been, be, lewisham,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to d: b, baum, dilation, wend, r, seperate, n, coincidentally,
# Nearest to however: but, although, though, that, where, which, while, when,
# Nearest to on: upon, through, in, within, zapotec, around, including, at,
# Nearest to this: which, it, the, that, some, another, ouadda, there,
# Average loss at step 72000: 3.371519
# Average loss at step 74000: 3.348103
# Average loss at step 76000: 3.312718
# Average loss at step 78000: 3.349308
# Average loss at step 80000: 3.384171
# Nearest to be: been, have, being, easily, were, prove, legally, is,
# Nearest to also: now, still, which, often, sometimes, sulba, algal, commonly,
# Nearest to have: had, has, be, are, having, were, prefer, knowledgeable,
# Nearest to years: days, months, decades, year, times, redding, weeks, stg,
# Nearest to system: systems, hoosiers, units, process, rhodope, designating, crowley, software,
# Nearest to united: chakras, usa, armed, fra, covariant, netherlands, kilometre, communist,
# Nearest to used: known, referred, written, defined, seen, considered, found, available,
# Nearest to not: still, never, always, generally, almost, actually, now, able,
# Nearest to were: are, had, was, have, those, being, dalmatian, been,
# Nearest to it: he, she, there, this, they, we, still, not,
# Nearest to was: is, became, were, had, has, been, being, sparked,
# Nearest to zero: four, five, seven, eight, six, nine, three, two,
# Nearest to d: b, f, seperate, entente, eschews, dilation, j, sol,
# Nearest to however: but, although, though, that, where, while, when, nevertheless,
# Nearest to on: upon, through, in, zapotec, scholastics, voluminous, against, within,
# Nearest to this: which, it, the, unexplained, there, he, itself, another,
# Average loss at step 82000: 3.405984
# Average loss at step 84000: 3.407203
# Average loss at step 86000: 3.393976
# Average loss at step 88000: 3.355780
# Average loss at step 90000: 3.365002
# Nearest to be: been, have, was, being, is, become, prove, refer,
# Nearest to also: now, often, which, still, sometimes, generally, usually, actually,
# Nearest to have: had, has, were, are, be, having, knowledgeable, prefer,
# Nearest to years: days, months, decades, year, weeks, hours, redding, stg,
# Nearest to system: systems, process, hoosiers, units, pedals, model, grim, bassists,
# Nearest to united: usa, chakras, armed, confederate, university, fra, gelfand, netherlands,
# Nearest to used: referred, known, written, seen, considered, found, designed, described,
# Nearest to not: still, never, generally, almost, now, able, actually, they,
# Nearest to were: are, had, have, was, while, being, those, these,
# Nearest to it: he, she, there, they, this, we, still, which,
# Nearest to was: is, became, had, were, has, been, be, wealthier,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to d: b, dilation, graduating, eschews, f, citation, suffolk, t,
# Nearest to however: but, although, though, that, while, since, where, when,
# Nearest to on: upon, through, against, at, under, zapotec, within, victoriae,
# Nearest to this: which, it, some, another, the, resignations, any, ouadda,
# Average loss at step 92000: 3.396424
# Average loss at step 94000: 3.253064
# Average loss at step 96000: 3.359321
# Average loss at step 98000: 3.240965
# Average loss at step 100000: 3.357568
# Nearest to be: been, being, prove, become, easily, have, are, produce,
# Nearest to also: now, still, actually, sometimes, generally, often, usually, never,
# Nearest to have: had, has, having, were, are, be, include, knowledgeable,
# Nearest to years: days, months, year, decades, weeks, hours, times, minutes,
# Nearest to system: systems, process, model, hoosiers, bassists, angevin, monitors, units,
# Nearest to united: usa, chakras, armed, confederate, netherlands, communist, gelfand, northern,
# Nearest to used: referred, written, known, considered, seen, defined, found, employed,
# Nearest to not: never, still, almost, generally, now, able, they, always,
# Nearest to were: are, was, had, have, those, being, these, is,
# Nearest to it: he, she, this, there, they, still, turquoise, which,
# Nearest to was: is, became, has, had, were, been, when, becomes,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to d: b, seperate, dilation, baum, francia, r, c, delta,
# Nearest to however: but, although, though, that, while, where, when, and,
# Nearest to on: upon, at, through, in, within, zapotec, against, under,
# Nearest to this: which, it, ouadda, another, he, some, advancing, the,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
